# %% [markdown]
# # top n reccommendation system

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer , CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from PIL import Image
import requests
from io import BytesIO
from ast import literal_eval
from nltk.stem.snowball import SnowballStemmer
import numpy as np
import warnings
warnings.filterwarnings('ignore')


dataPath = r'C:\Users\Abdo\Desktop\notFound2_metadata_votecount5407.csv'
ratingPath = r'C:\Users\Abdo\Desktop\notFound2_ratings5407.csv'

# %%
def img_show_indices( product_indices):
    fig, axs = plt.subplots(1, 10,figsize=(18,4))
    fig.suptitle('You may also like these products', size = 22)
    i = 0
    for ind in product_indices:
        response = requests.get(literal_eval(df2['imageURLHighRes'][ind])[0])
        img = Image.open(BytesIO(response.content))
        axs[i].imshow(img)
        axs[i].axis("off")
        axs[i].set_title('{}  '.format(round(df2['vote_average'][ind],2)),y=-0.18,color="red",fontsize=18)
        i = i+1
        fig.show()

# %%
def img_show_asin(asin):
    response = requests.get(literal_eval(df2[df2['asin'] == asin]['imageURLHighRes'].values[0])[0])
    img = Image.open(BytesIO(response.content))
    plt.imshow(img)
    plt.title(label= '{}  '.format(round(df2[df2['asin'] == asin]['vote_average'].values[0],2)) ,
          loc="right",
          color='red' , fontsize=18)
    plt.axis('off')
    plt.show()

# %%
df2= pd.read_csv(r'C:\Users\Abdo\Desktop\notFound2_metadata_votecount5407.csv')
df3= pd.read_csv(r'C:\Users\Abdo\Desktop\notFound2_ratings5407.csv')
df2['vote_average'].value_counts()
# Out:
# 3.000000    601
# 4.000000    447
# 3.500000    367
# 2.500000    287
# 2.000000    255
#            ...
# 3.019152      1
# 2.979275      1
# 3.789474      1
# 3.266067      1
# 3.873684      1
# Name: vote_average, Length: 654, dtype: int64

# %%
C= df2['vote_average'].mean()
m= df2['vote_count'].quantile(0.9)
df22 = df2.copy().loc[df2['vote_count'] >= m]

# %%
dataFramePhone = df22[df22['category'].str[2:27] == 'Cell Phones & Accessories']

dataFrameAppliances = df22[df22['category'].str[2:12] == 'Appliances']
dataFrameSports = df22[df22['category'].str[2:19] == 'Sports & Outdoors']

# %%
dataFramePhone
# Out:
#                                               category  \
# 7    ['Cell Phones & Accessories', 'Accessories', '...
# 21   ['Cell Phones & Accessories', 'Accessories', '...
# 28   ['Cell Phones & Accessories', 'Accessories', '...
# 73   ['Cell Phones & Accessories', 'Cases, Holsters...
# 78   ['Cell Phones & Accessories', 'Accessories', '...
# 80   ['Cell Phones & Accessories', 'Cases, Holsters...
# 92   ['Cell Phones & Accessories', 'Accessories', '...
# 94   ['Cell Phones & Accessories', 'Cases, Holsters...
# 97   ['Cell Phones & Accessories', 'Accessories', '...
# 115  ['Cell Phones & Accessories', 'Cases, Holsters...
# 122  ['Cell Phones & Accessories', 'Cases, Holsters...
# 128  ['Cell Phones & Accessories', 'Cases, Holsters...
# 148  ['Cell Phones & Accessories', 'Accessories', '...
# 158  ['Cell Phones & Accessories', 'Cases, Holsters...
# 167  ['Cell Phones & Accessories', 'Accessories', '...
# 170  ['Cell Phones & Accessories', 'Accessories', '...
# 206  ['Cell Phones & Accessories', 'Cases, Holsters...
# 211  ['Cell Phones & Accessories', 'Accessories', '...
# 226  ['Cell Phones & Accessories', 'Accessories', '...
# 265  ['Cell Phones & Accessories', 'Accessories', '...
# 276  ['Cell Phones & Accessories', 'Accessories', '...
# 281  ['Cell Phones & Accessories', 'Accessories', '...
# 282  ['Cell Phones & Accessories', 'Accessories', '...
# 309  ['Cell Phones & Accessories', 'Accessories', '...
# 321  ['Cell Phones & Accessories', 'Cases, Holsters...
# 331  ['Cell Phones & Accessories', 'Accessories', '...
# 333  ['Cell Phones & Accessories', 'Accessories', '...
# 337  ['Cell Phones & Accessories', 'Accessories', '...
# 369  ['Cell Phones & Accessories', 'SIM Cards & Pre...
# 387  ['Cell Phones & Accessories', 'Accessories', '...
# 413  ['Cell Phones & Accessories', 'Cases, Holsters...
# 457  ['Cell Phones & Accessories', 'Accessories', '...
# 477  ['Cell Phones & Accessories', 'Accessories', '...
# 478  ['Cell Phones & Accessories', 'Accessories', '...
# 500  ['Cell Phones & Accessories', 'Accessories', '...
# 513  ['Cell Phones & Accessories', 'Accessories', '...
# 515  ['Cell Phones & Accessories', 'Cases, Holsters...
# 516  ['Cell Phones & Accessories', 'Cases, Holsters...
# 533  ['Cell Phones & Accessories', 'Accessories', '...
# 540  ['Cell Phones & Accessories', 'Accessories', '...
# 543  ['Cell Phones & Accessories', 'Accessories', '...
# 548  ['Cell Phones & Accessories', 'Accessories', '...
# 616  ['Cell Phones & Accessories', 'Accessories', '...
# 650  ['Cell Phones & Accessories', 'Accessories', '...
# 670  ['Cell Phones & Accessories', 'Accessories', '...
# 684  ['Cell Phones & Accessories', 'Accessories', '...
# 715  ['Cell Phones & Accessories', 'Accessories', '...
# 732  ['Cell Phones & Accessories', 'Accessories', '...
# 760  ['Cell Phones & Accessories', 'Accessories', '...
# 761  ['Cell Phones & Accessories', 'Accessories', '...
# 788  ['Cell Phones & Accessories', 'Accessories', '...
#
#                                                  tech1  \
# 7                                                  NaN
# 21    class="a-keyvalue prodDetTable" role="present...
# 28                                                 NaN
# 73                                                 NaN
# 78                                                 NaN
# 80                                                 NaN
# 92    class="a-keyvalue prodDetTable" role="present...
# 94                                                 NaN
# 97                                                 NaN
# 115                                                NaN
# 122                                                NaN
# 128                                                NaN
# 148                                                NaN
# 158                                                NaN
# 167   class="a-keyvalue prodDetTable" role="present...
# 170   class="a-keyvalue prodDetTable" role="present...
# 206                                                NaN
# 211   class="a-keyvalue prodDetTable" role="present...
# 226   class="a-keyvalue prodDetTable" role="present...
# 265                                                NaN
# 276                                                NaN
# 281                                                NaN
# 282                                                NaN
# 309   class="a-keyvalue prodDetTable" role="present...
# 321   class="a-keyvalue prodDetTable" role="present...
# 331                                                NaN
# 333                                                NaN
# 337                                                NaN
# 369   class="a-keyvalue prodDetTable" role="present...
# 387                                                NaN
# 413                                                NaN
# 457                                                NaN
# 477                                                NaN
# 478                                                NaN
# 500                                                NaN
# 513                                                NaN
# 515                                                NaN
# 516                                                NaN
# 533                                                NaN
# 540                                                NaN
# 543                                                NaN
# 548   class="a-keyvalue prodDetTable" role="present...
# 616                                                NaN
# 650                                                NaN
# 670                                                NaN
# 684   class="a-keyvalue prodDetTable" role="present...
# 715   class="a-keyvalue prodDetTable" role="present...
# 732                                                NaN
# 760                                                NaN
# 761                                                NaN
# 788                                                NaN
#
#                                            description  fit  \
# 7    ['<b>Package Includes:</b><br/><ul><li>1 x Swi...  NaN
# 21   ['', '<b>BESTEK 4-in-1 DC Auto Adapter expends...  NaN
# 28   ['<b></b>', '<b>One of the Best iphone 4 4S sc...  NaN
# 73                  ['<b>Description', '', '', '', '']  NaN
# 78   ['<b>', 'One of the Best Apple iPhone 5 screen...  NaN
# 80   ['Rechargeable External Battery Case made for ...  NaN
# 92   ['<b>High quality:</b> <br> - Shell: sturdy an...  NaN
# 94   ['', 'Following up on our original Superlegger...  NaN
# 97   ["Use RND Power Solutions <b>BEST SELLING</b> ...  NaN
# 115  ["<b>Acases' top rated iphone 4/5 case is now ...  NaN
# 122  ['When it comes to phone cases, nobody knows b...  NaN
# 128  ['', 'Poetic, an SmartShop Online Inc Brand, w...  NaN
# 148  ['', '<b>Feature:</b>', '<b>Compatible with:</...  NaN
# 158  ['i-Blason Samsung Galaxy S4 Active Prime Seri...  NaN
# 167  ['', '<span style="font-size: 12.0pt; font-fam...  NaN
# 170  ["Ideal for syncing and charging your newer iP...  NaN
# 206  ['', 'Nite Ize makes products that help you in...  NaN
# 211  ['<div class="aplus"> <div class="leftImage" s...  NaN
# 226  ['This is a USB 3.0 A (male) to Micro-USB 3.0 ...  NaN
# 265  ['<b>Note:</b><br>1.Would not power up a devic...  NaN
# 276  ['Compatible with all smartphones. Cradle-less...  NaN
# 281  ['', '<b>iClever</b> - Ever Clever', 'iClever ...  NaN
# 282  ['Quick, Convenient and Hands-Free; the MagicM...  NaN
# 309  ["Lasting comfort and easy controls. The Plant...  NaN
# 321  ['Supcase Samsung galaxy Tab 4 7.0 unicorn bee...  NaN
# 331  ['Ships with Epic Gadget(TM) packing in United...  NaN
# 333  ['1. Tempered Glass Screen Protector Features ...  NaN
# 337  ['Braided Micro-USB Data Sync & Charging cable.']  NaN
# 369  ['New, Sealed, Never Used, Never Activated. Mi...  NaN
# 387  ['1. Features & Advantages. <br><br> -- Premiu...  NaN
# 413  ['<b>Not suitable for iPhone X , iPhone XS</b>...  NaN
# 457  ['<b>Quick PD Car Charger with USB C to C cabl...  NaN
# 477  ['Ships with Epic Gadget(TM) packing in United...  NaN
# 478  ["Note: If magnet is too strong that sometimes...  NaN
# 500  ["Use RND Power Solutions <b>BEST SELLING</b> ...  NaN
# 513  ['<b>WizGear Universal Air Vent Magnetic Car M...  NaN
# 515  ["The Defender Series case provides heavy duty...  NaN
# 516  ["The Defender Series case provides heavy duty...  NaN
# 533  ['3 in 1 Lens Kit includes:<br>1.Macro lens fo...  NaN
# 540  ['Plantronics Explorer 50 Bluetooth Headset - ...  NaN
# 543  ["Our Selfie Stick is designed with FUN, FUNCT...  NaN
# 548  ['', '<span style="font-size: 12.0pt; font-fam...  NaN
# 616  ['', 'CableCreation Focus to the Ideal Design ...  NaN
# 650  ['1. Tempered Glass Screen Protector Features ...  NaN
# 670  ['for our brand CHOETECH<br> Expert in chargin...  NaN
# 684  ["Product Description Compact and Power Packed...  NaN
# 715  ['Description:  Amaz247 double clip 360 rotati...  NaN
# 732  ['. WHY SHOULD YOU BUY TECHARMOR BALLISTIC GLA...  NaN
# 760  ['<b>Broaden Your Horizons</b> <br>See more th...  NaN
# 761  ['', '<b>Mr Shield Screen Protector Kit Includ...  NaN
# 788  ['<b>Description</b><br> Ugreen Micro USB 2.0 ...  NaN
#
#                                                  title  \
# 7    Universal Car Windshield Mount Holder for Appl...
# 21   BESTEK 150W 2-Socket Cigarette Lighter Power A...
# 28   Acase Screen Protector Film Clear (Invisible) ...
# 73   Apple iPhone 5/5S/SE Case - Poetic [Atmosphere...
# 78   Acase iPhone 5S / iPhone 5C / iPhone 5 Premium...
# 80   mophie juice pack for Samsung Galaxy SIII (2,3...
# 92   EasyAcc 5V 2A Micro USB Travel Charger Portabl...
# 94   Acase iPhone 5s Case / iPhone 5 case - Superle...
# 97   RND Apple Certified Lightning USB 6ft Cable fo...
# 115  Acase Superleggera Pro Hybrid dual layer Case ...
# 122  Bear Motion (TM) Premium Slim Back Cover Case ...
# 128  HTC One M7 Case - Poetic HTC One M7 Case [Atmo...
# 148  HD Lens Apexel Universal Professional HD Camer...
# 158  i-Blason Samsung Galaxy S4 Active (i9295 Water...
# 167  KFK Compatible Adapter Splitter Replacement fo...
# 170  Tech Armor Apple MFi Certified Lightning Cable...
# 206  Nite Ize Clip Case Sideways Phone Holster - Pr...
# 211  StarTech.com 1U 12 Port Wall Mount Cat5e 110 P...
# 226  iMBAPrice 15-Feet Long Super Speed 5Gbps USB 3...
# 265  RAVPower AC Outlet Portable Charger RAVPower 2...
# 276  Koomus Magnetos CD Magnetic Cradle-less Smartp...
# 281  iClever Car Mount 360 Degree Rotation Universa...
# 282  SCOSCHE MAGDM MagicMount Universal Magnetic Ph...
# 309  Plantronics M70 Bluetooth Headset - Retail Pac...
# 321  SUPCASE Galaxy Tab 4 7.0(T230 /T231/ T235) Cas...
# 331  EpicGadget(TM) Green and Orange Durable Heavy ...
# 333  iCarez [Tempered Glass Screen Protector for LG...
# 337  1M Braided Micro-USB Charger Cable for Galaxy ...
# 369          T-Mobile Prepaid Complete SIM Starter Kit
# 387  iCarez Anti Glare (Matte) Premium Screen Prote...
# 413  De-Bin iPhone XS Max Holster Case, iPhone 6 Pl...
# 457  Eleckey ASIA255 Rapid USB PD Car Charger for G...
# 477  EpicGadget(TM) Green and Orange Durable Heavy ...
# 478  Car Mount, Nexcon Magnetic Cradle-less Univers...
# 500  RND Apple Certified Lightning USB 6ft Cable fo...
# 513  WizGear Car Mount, Universal Air Vent Magnetic...
# 515  OtterBox DEFENDER SERIES for Samsung  Galaxy S...
# 516  OtterBox DEFENDER SERIES for Samsung  Galaxy S...
# 533  Neewer 3-in-1 Clip-on Lens for iPhone X 8 7 6,...
# 540  Plantronics Explorer 50 Bluetooth Headset - Re...
# 543  Fugetek FT-568 Rated Best Selfie Stick in 2015...
# 548  Vastar Premium 4 in 1 Multiple USB Charging Ca...
# 616  Type USB C-C Cable, CableCreation 10ft Braided...
# 650  iCarez Tempered Glass Screen Protector for Hua...
# 670  CHOETECH USB C Charger, 18W Type-C Power Deliv...
# 684  American Red Cross ARCCR100R-DBL Clipray the C...
# 715  EAGWELL Universal 360 Degree Rotating Flexible...
# 732  Tech Armor Galaxy S7 Glass Screen Protector, P...
# 760  AUKEY Ora iPhone Camera Lens, 0.45x 140&deg; W...
# 761  Mr Shield Tempered Glass Screen Protector for ...
# 788  UGREEN Micro USB Cable, USB 2.0 A Male to Micr...
#
#                                               also_buy  \
# 7                                                   []
# 21                                                  []
# 28                                                  []
# 73                        ['B01GU935VA', 'B01C6HW750']
# 78                                                  []
# 80   ['B0089VO7OM', 'B00A44JSFK', 'B00KNJJPSG', 'B0...
# 92                                                  []
# 94                                                  []
# 97   ['B00G8OH09Q', 'B00BN20AS6', 'B00AGJML20', 'B0...
# 115                                                 []
# 122                                                 []
# 128                                                 []
# 148                                     ['B00EY2Q1AS']
# 158  ['B01JOG2FOO', 'B00LX02I92', 'B01EMRSRDI', 'B0...
# 167  ['B015QZJ52C', 'B015SI4PF4', 'B01NCSLLHQ', 'B0...
# 170  ['B0771RQL3F', 'B016QW63FG', 'B07GZZXBTG', 'B0...
# 206  ['B0142LUNMW', 'B00GOZOGL4', 'B00N24XIHS', 'B0...
# 211                                                 []
# 226                                                 []
# 265                                                 []
# 276  ['B016GNZ06I', 'B07K92QZ4M', 'B00SZ2SIDQ', 'B0...
# 281                                                 []
# 282  ['B00I608BG6', 'B00R2K4LCY', 'B00I608BFW', 'B0...
# 309  ['B00QWDGFN0', 'B00V5AEW9O', 'B071YZ4F3Y', 'B0...
# 321                                                 []
# 331                                                 []
# 333  ['B00L9OVC94', 'B00KOIGYS0', 'B00JW7APWU', 'B0...
# 337                                                 []
# 369  ['B07KP82TMB', 'B01M7W3AUU', 'B00I1W6FDA', 'B0...
# 387  ['B01J5FO2X6', 'B074GYB4RJ', 'B00FCCRG7G', 'B0...
# 413  ['B00NKA4NQY', 'B01LDWDO1A', 'B015TDZETY', 'B0...
# 457  ['B07H5T6DQ8', 'B07HHMLVM9', 'B07H8ZNZJ8', 'B0...
# 477                                                 []
# 478  ['B07GD9P93T', 'B00032S02K', 'B019GUS312', 'B0...
# 500  ['B00B3NI4Y2', 'B00BN208GA', 'B00BR7S9SA', 'B0...
# 513  ['B072M7SQQQ', 'B01B6K2GDQ', 'B077MTNV41', 'B0...
# 515  ['B01JCQUNPE', 'B01D0JV7AO', 'B00XFRUTXI', 'B0...
# 516  ['B01JCQUNPE', 'B01D0JV7AO', 'B00XFRUTXI', 'B0...
# 533  ['B01LYLSOXN', 'B018ICYNKY', 'B074Q6TFJC', 'B0...
# 540  ['B00QWDGFN0', 'B01320ZGMQ', 'B00DQ5RHK2', 'B0...
# 543                                                 []
# 548  ['B0761TDXRS', 'B07528W1M2', 'B00FFJDA12', 'B0...
# 616  ['B07GWNYC4W', 'B0721DV7YX', 'B017I7EX46', 'B0...
# 650  ['B016CBFBVI', 'B015X90UJS', 'B015X9UR2S', 'B0...
# 670  ['B01GGKZ1VA', 'B0747669PT', 'B01D175HMO', 'B0...
# 684  ['B00HSHH5DI', 'B0045W0MD4', 'B00UTKQ1P4', 'B0...
# 715  ['B01M32NEZE', 'B01M58S2G9', 'B01M0IS0AK', 'B0...
# 732  ['B06Y5P7BCX', 'B00U6EZC5S', 'B00IGISUTG', 'B0...
# 760                                                 []
# 761  ['B077VWZ8TP', 'B017SF2KHA', 'B0147JXUVU', 'B0...
# 788  ['B01N4B9WQQ', 'B01MXVJIWJ', 'B01MTXZ3U8', 'B0...
#
#                                                  tech2                brand  \
# 7                                                  NaN               iKross
# 21                                                 NaN               BESTEK
# 28                                                 NaN                Acase
# 73                                                 NaN               Poetic
# 78                                                 NaN                Acase
# 80                                                 NaN               mophie
# 92                                                 NaN              EasyAcc
# 94                                                 NaN                Acase
# 97                                                 NaN  RND Power Solutions
# 115                                                NaN                Acase
# 122                                                NaN          Bear Motion
# 128                                                NaN               Poetic
# 148                                                NaN               Apexel
# 158                                                NaN             i-Blason
# 167                                                NaN                 MECO
# 170                                                NaN           Tech Armor
# 206                                                NaN             Nite Ize
# 211                                                NaN             StarTech
# 226                                                NaN            iMBAPrice
# 265                                                NaN             RAVPower
# 276                                                NaN               Koomus
# 281                                                NaN              iClever
# 282                                                NaN              Scosche
# 309                                                NaN          Plantronics
# 321   class="a-keyvalue prodDetTable" role="present...              SUPCASE
# 331                                                NaN       EpicGadget(TM)
# 333                                                NaN               iCarez
# 337                                                NaN              Gonezon
# 369                                                NaN             T-Mobile
# 387                                                NaN               iCarez
# 413                                                NaN                Debin
# 457                                                NaN              Eleckey
# 477                                                NaN       EpicGadget(TM)
# 478                                                NaN               Nexcon
# 500                                                NaN  RND Power Solutions
# 513                                                NaN              WizGear
# 515                                                NaN             OtterBox
# 516                                                NaN             OtterBox
# 533                                                NaN               Neewer
# 540                                                NaN          Plantronics
# 543                                                NaN             Fugetek.
# 548                                                NaN               Vastar
# 616                                                NaN        CableCreation
# 650                                                NaN               iCarez
# 670                                                NaN             CHOETECH
# 684                                                NaN                 Eton
# 715                                                NaN              EAGWELL
# 732                                                NaN           Tech Armor
# 760                                                NaN                AUKEY
# 761                                                NaN            Mr Shield
# 788                                                NaN               UGREEN
#
#                                                feature  \
# 7    ['Easily attach & secure vacuum base to windsh...
# 21   ['BESTEK Advantage:Two 12V / 24V cigarette lig...
# 28   ['Heavy duty screen protector, 100% guarantee ...
# 73   ['Made from dual-injected durable polycarbonat...
# 78   ['Designed Compatible with the Apple iPhone 5 ...
# 80   ['Rechargeable 2300mAh battery extender and pr...
# 92   ['Ultra long cable length up to 4 Feet for mor...
# 94   ['Compatibility: iPhone 5s & iPhone 5 - (16GB ...
# 97   ["Apple MFi certified - Our premium cable is A...
# 115  ['Compatibility: LG Google Nexus 4', 'Combines...
# 122  ['Access to all ports and controls without tak...
# 128  ['Made of polycarbonate and thermoplastic poly...
# 148  ['New design universal clip can attach every 3...
# 158  ['i-Blason (TM) Logo Bearing Dual Layer Kick S...
# 167  ['Audio & Charge: Designed for iP X / 8 / 8 Pl...
# 170  ['Compatible Model(s): All USB Lightning Charg...
# 206  ['PROTECT YOUR PHONE WITH THE BEST - This dura...
# 211  ['Charge or sync your Micro USB devices with t...
# 226  ['Connectors: USB 3.0 A (Male) - to - Micro US...
# 265  ['New-and-Improved Version: 3-prong AC output ...
# 276  ['Universal Smartphone, Cellphone mount compat...
# 281  ['Allows full 360 rotation for portrait and la...
# 282  ['VERSATILE: Safely and quickly secure a mobil...
# 309  ["The lightweight design and soft ear tip let ...
# 321  ['Precise cutouts for Samsung Galaxy Tab 4 7.0...
# 331  ['Quick shipping, high quality!! US Seller!!',...
# 333  ['Tempered Glass Anti-scratch for LG G3 (Hardn...
# 337  ['Length: 1 m', 'Braided Micro-USB Data Sync &...
# 369  ['Buying an unlocked, compatible phone or tabl...
# 387  ['Hard coated for Scratch Proof (Hardness: 3H-...
# 413  ['Specifically designed for iPhone 6 PLUS 5.5"...
# 457  ['Qualcomm Certified Dual Quick Charge 3.0 -Th...
# 477  ['Quick shipping, high quality!! US Seller!!',...
# 478  ['Magnetic and Cradle-less design, with Super ...
# 500  ["APPLE MFi CERTIFIED - Our premium cable is A...
# 513  ['POWERFUL MAGNETIC MOUNT; The reinforced magn...
# 515  ['Compatible with Samsung Galaxy S6', 'Robust,...
# 516  ['Compatible with Samsung Galaxy S6', 'Robust,...
# 533  ['This is a 3 in 1 clip-on detachable lens kit...
# 540  ['Talk time: 11 hours, Deep Sleep mode allows ...
# 543  ['WOBBLE FREE SELFIES, SUPERIOR QUALITY, COMPA...
# 548  ['1M/3.3FT Vastar 3-in-1 charging cable allows...
# 616  ['Type-C (USB-C) plug is reversible design; Fa...
# 650  ['New Glass Anti-scratch for Huawei Google Nex...
# 670  ['18W High-Speed ChargingUSB C and Power Deliv...
# 684  ['Crank powered USB cell phone charger', 'Powe...
# 715  ['Specially design for iPhones 6S Plus/6S/5S/5...
# 732  ['Compatible Model(s): Galaxy S7 by Samsung [1...
# 760  ['Premium Lenses: The Ora 2-in-1 Lens Kit incl...
# 761  ['Include 2 pcs Tempered Glass Screen Protecto...
# 788  ['UTILITY: Ugreen micro usb cable is ideal for...
#
#                                                   rank  ... details  \
# 7    ['>#607,556 in Cell Phones & Accessories (See ...  ...      {}
# 21   ['>#7,466 in Automotive (See top 100)', '>#325...  ...      {}
# 28   ['>#284,257 in Cell Phones & Accessories (See ...  ...      {}
# 73   ['>#170,150 in Cell Phones & Accessories (See ...  ...      {}
# 78   ['>#437,470 in Cell Phones & Accessories (See ...  ...      {}
# 80   ['>#67,659 in Cell Phones & Accessories (See T...  ...      {}
# 92   ['>#29,496 in Cell Phones & Accessories (See t...  ...      {}
# 94   ['>#532,622 in Cell Phones & Accessories (See ...  ...      {}
# 97   ['>#26,325 in Cell Phones & Accessories (See T...  ...      {}
# 115  ['>#1,009,583 in Cell Phones & Accessories (Se...  ...      {}
# 122  ['>#2,091,384 in Cell Phones & Accessories (Se...  ...      {}
# 128  ['>#827,944 in Cell Phones & Accessories (See ...  ...      {}
# 148  ['>#5,710 in Camera & Photo (See Top 100 in Ca...  ...      {}
# 158  ['>#164,493 in Cell Phones & Accessories (See ...  ...      {}
# 167  ['>#120,969 in Cell Phones & Accessories (See ...  ...      {}
# 170  ['>#23,521 in Cell Phones & Accessories (See t...  ...      {}
# 206  ['>#12,808 in Cell Phones & Accessories (See T...  ...      {}
# 211  ['>#573,050 in Cell Phones & Accessories (See ...  ...      {}
# 226  ['>#527,829 in Cell Phones & Accessories (See ...  ...      {}
# 265  ['>#13,173 in Cell Phones & Accessories (See T...  ...      {}
# 276  ['>#8,959 in Cell Phones & Accessories (See To...  ...      {}
# 281  ['>#145,677 in Cell Phones & Accessories (See ...  ...      {}
# 282  ['>#351 in Kitchen & Dining (See Top 100 in Ki...  ...      {}
# 309  ['>#1,546 in Cell Phones & Accessories (See to...  ...      {}
# 321  ['>#37,578 in Cell Phones & Accessories (See t...  ...      {}
# 331  ['>#468,034 in Cell Phones & Accessories (See ...  ...      {}
# 333  ['>#25,740 in Cell Phones & Accessories (See T...  ...      {}
# 337  ['>#1,169,048 in Cell Phones & Accessories (Se...  ...      {}
# 369  ['>#1,214 in Cell Phones & Accessories (See to...  ...      {}
# 387  ['>#5,406 in Cell Phones & Accessories (See To...  ...      {}
# 413  ['>#14,640 in Cell Phones & Accessories (See T...  ...      {}
# 457  ['>#57,699 in Cell Phones & Accessories (See T...  ...      {}
# 477  ['>#469,225 in Cell Phones & Accessories (See ...  ...      {}
# 478  ['>#37,125 in Cell Phones & Accessories (See T...  ...      {}
# 500  ['>#25,855 in Cell Phones & Accessories (See T...  ...      {}
# 513  ['>#25,720 in Cell Phones & Accessories (See T...  ...      {}
# 515  ['>#2,709 in Cell Phones & Accessories (See To...  ...      {}
# 516  ['>#2,709 in Cell Phones & Accessories (See To...  ...      {}
# 533  ['>#9,761 in Camera & Photo (See Top 100 in Ca...  ...      {}
# 540  ['>#309 in Cell Phones & Accessories (See Top ...  ...      {}
# 543  ['>#72 in Camera & Photo (See Top 100 in Camer...  ...      {}
# 548  ['>#7,804 in Cell Phones & Accessories (See to...  ...      {}
# 616  ['>#43,297 in Cell Phones & Accessories (See T...  ...      {}
# 650  ['>#14,781 in Cell Phones & Accessories (See T...  ...      {}
# 670  ['>#14,700 in Cell Phones & Accessories (See T...  ...      {}
# 684  ['>#191,245 in Tools & Home Improvement (See t...  ...      {}
# 715  ['>#111,179 in Cell Phones & Accessories (See ...  ...      {}
# 732  ['>#37,789 in Cell Phones & Accessories (See T...  ...      {}
# 760  ['>#437 in Camera & Photo (See Top 100 in Came...  ...      {}
# 761  ['>#15,858 in Cell Phones & Accessories (See T...  ...      {}
# 788  ['>#145,394 in Cell Phones & Accessories (See ...  ...      {}
#
#                       main_cat  \
# 7              All Electronics
# 21                  Automotive
# 28   Cell Phones & Accessories
# 73   Cell Phones & Accessories
# 78   Cell Phones & Accessories
# 80   Cell Phones & Accessories
# 92                   Computers
# 94   Cell Phones & Accessories
# 97   Cell Phones & Accessories
# 115  Cell Phones & Accessories
# 122  Cell Phones & Accessories
# 128  Cell Phones & Accessories
# 148             Camera & Photo
# 158  Cell Phones & Accessories
# 167                  Computers
# 170  Cell Phones & Accessories
# 206  Cell Phones & Accessories
# 211                  Computers
# 226                  Computers
# 265             Camera & Photo
# 276  Cell Phones & Accessories
# 281            All Electronics
# 282                Amazon Home
# 309  Cell Phones & Accessories
# 321                  Computers
# 331  Cell Phones & Accessories
# 333            All Electronics
# 337                  Computers
# 369  Cell Phones & Accessories
# 387            All Electronics
# 413            All Electronics
# 457            All Electronics
# 477  Cell Phones & Accessories
# 478            All Electronics
# 500  Cell Phones & Accessories
# 513            All Electronics
# 515  Cell Phones & Accessories
# 516  Cell Phones & Accessories
# 533             Camera & Photo
# 540  Cell Phones & Accessories
# 543             Camera & Photo
# 548  Cell Phones & Accessories
# 616                  Computers
# 650            All Electronics
# 670            All Electronics
# 684   Tools & Home Improvement
# 715  Cell Phones & Accessories
# 732            All Electronics
# 760             Camera & Photo
# 761            All Electronics
# 788  Cell Phones & Accessories
#
#                                           similar_item                date  \
# 7     class="a-bordered a-horizontal-stripes  a-spa...        May 10, 2004
# 21    class="a-bordered a-horizontal-stripes  a-spa...       June 13, 2010
# 28    class="a-bordered a-horizontal-stripes  a-spa...     August 23, 2010
# 73    class="a-bordered a-horizontal-stripes  a-spa...     August 28, 2012
# 78                                                 NaN  September 14, 2012
# 80                                                 NaN       June 29, 2017
# 92    class="a-bordered a-horizontal-stripes  a-spa...   November 19, 2012
# 94                                                 NaN   November 20, 2012
# 97    class="a-bordered a-horizontal-stripes  a-spa...   February 28, 2013
# 115                                                NaN    January 19, 2013
# 122                                                NaN    October 21, 2012
# 128                                                NaN       March 7, 2013
# 148   class="a-bordered a-horizontal-stripes  a-spa...        May 15, 2013
# 158   class="a-bordered a-horizontal-stripes  a-spa...       June 23, 2013
# 167                                                NaN       July 15, 2013
# 170   class="a-bordered a-horizontal-stripes  a-spa...       July 16, 2013
# 206   class="a-bordered a-horizontal-stripes  a-spa...    November 1, 2013
# 211                                                NaN  September 16, 2013
# 226   class="a-bordered a-horizontal-stripes  a-spa...     October 9, 2013
# 265   class="a-bordered a-horizontal-stripes  a-spa...   December 20, 2013
# 276   class="a-bordered a-horizontal-stripes  a-spa...    January 14, 2014
# 281   class="a-bordered a-horizontal-stripes  a-spa...     August 29, 2013
# 282   class="a-bordered a-horizontal-stripes  a-spa...    January 24, 2014
# 309                                                NaN       April 1, 2014
# 321   class="a-bordered a-horizontal-stripes  a-spa...         May 6, 2014
# 331                                                NaN        May 20, 2014
# 333   class="a-bordered a-horizontal-stripes  a-spa...        May 21, 2014
# 337   class="a-bordered a-horizontal-stripes  a-spa...       June 22, 2017
# 369   class="a-bordered a-horizontal-stripes  a-spa...       March 1, 2018
# 387   class="a-bordered a-horizontal-stripes  a-spa...     August 27, 2014
# 413   class="a-bordered a-horizontal-stripes  a-spa...  September 11, 2014
# 457   class="a-bordered a-horizontal-stripes  a-spa...    November 4, 2014
# 477                                                NaN        May 20, 2014
# 478   class="a-bordered a-horizontal-stripes  a-spa...   November 28, 2014
# 500   class="a-bordered a-horizontal-stripes  a-spa...    December 1, 2012
# 513   class="a-bordered a-horizontal-stripes  a-spa...   February 19, 2015
# 515   class="a-bordered a-horizontal-stripes  a-spa...       April 1, 2014
# 516   class="a-bordered a-horizontal-stripes  a-spa...       April 1, 2014
# 533   class="a-bordered a-horizontal-stripes  a-spa...      March 24, 2015
# 540                                                NaN       March 1, 2015
# 543   class="a-bordered a-horizontal-stripes  a-spa...      April 16, 2015
# 548   class="a-bordered a-horizontal-stripes  a-spa...      April 21, 2015
# 616   class="a-bordered a-horizontal-stripes  a-spa...      August 5, 2015
# 650   class="a-bordered a-horizontal-stripes  a-spa...     October 6, 2015
# 670   class="a-bordered a-horizontal-stripes  a-spa...    November 3, 2015
# 684                                                NaN   November 19, 2015
# 715   class="a-bordered a-horizontal-stripes  a-spa...    January 13, 2016
# 732   class="a-bordered a-horizontal-stripes  a-spa...   February 15, 2016
# 760                                                NaN      March 21, 2016
# 761                                                NaN      April 28, 2016
# 788   class="a-bordered a-horizontal-stripes  a-spa...    October 22, 2016
#
#        price        asin                                           imageURL  \
# 7      $6.63  B0011YO8S4  ['https://images-na.ssl-images-amazon.com/imag...
# 21     $1.96  B003RQBKLC  ['https://images-na.ssl-images-amazon.com/imag...
# 28     $7.98  B0040I5CME  ['https://images-na.ssl-images-amazon.com/imag...
# 73    $12.95  B0093CDLM0  ['https://images-na.ssl-images-amazon.com/imag...
# 78     $3.30  B009B127NW  ['https://images-na.ssl-images-amazon.com/imag...
# 80    $12.98  B009C2ZNA4  ['https://images-na.ssl-images-amazon.com/imag...
# 92     $9.99  B00A9PO5AM  ['https://images-na.ssl-images-amazon.com/imag...
# 94    $10.95  B00AAJDASK  ['https://images-na.ssl-images-amazon.com/imag...
# 97     $9.36  B00AGJMMVA  ['https://images-na.ssl-images-amazon.com/imag...
# 115   $30.52  B00B4U5LU4  ['https://images-na.ssl-images-amazon.com/imag...
# 122    $6.99  B00BFPVCRE  ['https://images-na.ssl-images-amazon.com/imag...
# 128    $9.95  B00BQ2Y458  ['https://images-na.ssl-images-amazon.com/imag...
# 148    $5.52  B00CSJ90Q6  ['https://images-na.ssl-images-amazon.com/imag...
# 158   $24.00  B00DJZZ9W2  ['https://images-na.ssl-images-amazon.com/imag...
# 167   $21.51  B00DXZKYTQ  ['https://images-na.ssl-images-amazon.com/imag...
# 170   $14.95  B00DZ0JAMG  ['https://images-na.ssl-images-amazon.com/imag...
# 206   $12.17  B00F36YKFC  ['https://images-na.ssl-images-amazon.com/imag...
# 211    $6.74  B00F7QKHFA  ['https://images-na.ssl-images-amazon.com/imag...
# 226    $7.99  B00FQPGAHG  ['https://images-na.ssl-images-amazon.com/imag...
# 265  $129.99  B00HFMUBYG  ['https://images-na.ssl-images-amazon.com/imag...
# 276   $14.99  B00HUIL310  ['https://images-na.ssl-images-amazon.com/imag...
# 281    $1.96  B00HZDX42G  ['https://images-na.ssl-images-amazon.com/imag...
# 282    $1.96  B00I3E17RA  ['https://images-na.ssl-images-amazon.com/imag...
# 309    $6.04  B00JEI9M1W  ['https://images-na.ssl-images-amazon.com/imag...
# 321   $19.99  B00K5NYTCM  ['https://images-na.ssl-images-amazon.com/imag...
# 331    $4.69  B00KDQSGD4  ['https://images-na.ssl-images-amazon.com/imag...
# 333    $5.95  B00KGSW734  ['https://images-na.ssl-images-amazon.com/imag...
# 337    $2.99  B00KJ67ZDK  ['https://images-na.ssl-images-amazon.com/imag...
# 369    $9.90  B00LPPHHFK  ['https://images-na.ssl-images-amazon.com/imag...
# 387    $5.85  B00N2KYBSW  ['https://images-na.ssl-images-amazon.com/imag...
# 413    $9.99  B00NH7Z2J2  ['https://images-na.ssl-images-amazon.com/imag...
# 457   $15.99  B00P7VSRFC  ['https://images-na.ssl-images-amazon.com/imag...
# 477    $4.69  B00Q5OS8EA  ['https://images-na.ssl-images-amazon.com/imag...
# 478    $4.99  B00QAXY27S  ['https://images-na.ssl-images-amazon.com/imag...
# 500    $9.36  B00SST0U1O  ['https://images-na.ssl-images-amazon.com/imag...
# 513    $8.99  B00TRQIXWA  ['https://images-na.ssl-images-amazon.com/imag...
# 515   $23.91  B00TYTBFSO  ['https://images-na.ssl-images-amazon.com/imag...
# 516   $23.91  B00TYTBGOC  ['https://images-na.ssl-images-amazon.com/imag...
# 533    $4.99  B00V4MMA38  ['https://images-na.ssl-images-amazon.com/imag...
# 540    $6.04  B00W3TAMG8  ['https://images-na.ssl-images-amazon.com/imag...
# 543    $5.53  B00W77LAAI  ['https://images-na.ssl-images-amazon.com/imag...
# 548    $6.99  B00WFNNJB2  ['https://images-na.ssl-images-amazon.com/imag...
# 616    $7.99  B013G4C41E  ['https://images-na.ssl-images-amazon.com/imag...
# 650    $7.85  B0168XT3E6  ['https://images-na.ssl-images-amazon.com/imag...
# 670   $13.99  B017I7EX46  ['https://images-na.ssl-images-amazon.com/imag...
# 684   $24.99  B0188PGDOK  ['https://images-na.ssl-images-amazon.com/imag...
# 715    $7.99  B01AJVN8VM  ['https://images-na.ssl-images-amazon.com/imag...
# 732    $7.95  B01BT16Y9Y  ['https://images-na.ssl-images-amazon.com/imag...
# 760   $19.99  B01D8KOAWM  ['https://images-na.ssl-images-amazon.com/imag...
# 761    $6.95  B01D9EMSGC  ['https://images-na.ssl-images-amazon.com/imag...
# 788    $5.59  B01EUSL4CU  ['https://images-na.ssl-images-amazon.com/imag...
#
#                                        imageURLHighRes vote_count  \
# 7    ['https://images-na.ssl-images-amazon.com/imag...        156
# 21   ['https://images-na.ssl-images-amazon.com/imag...         54
# 28   ['https://images-na.ssl-images-amazon.com/imag...         43
# 73   ['https://images-na.ssl-images-amazon.com/imag...         57
# 78   ['https://images-na.ssl-images-amazon.com/imag...         23
# 80   ['https://images-na.ssl-images-amazon.com/imag...         25
# 92   ['https://images-na.ssl-images-amazon.com/imag...         24
# 94   ['https://images-na.ssl-images-amazon.com/imag...        100
# 97   ['https://images-na.ssl-images-amazon.com/imag...        595
# 115  ['https://images-na.ssl-images-amazon.com/imag...         30
# 122  ['https://images-na.ssl-images-amazon.com/imag...         39
# 128  ['https://images-na.ssl-images-amazon.com/imag...         34
# 148  ['https://images-na.ssl-images-amazon.com/imag...         26
# 158  ['https://images-na.ssl-images-amazon.com/imag...         28
# 167  ['https://images-na.ssl-images-amazon.com/imag...         26
# 170  ['https://images-na.ssl-images-amazon.com/imag...         37
# 206  ['https://images-na.ssl-images-amazon.com/imag...         28
# 211  ['https://images-na.ssl-images-amazon.com/imag...         26
# 226  ['https://images-na.ssl-images-amazon.com/imag...         35
# 265  ['https://images-na.ssl-images-amazon.com/imag...         27
# 276  ['https://images-na.ssl-images-amazon.com/imag...         63
# 281  ['https://images-na.ssl-images-amazon.com/imag...         25
# 282  ['https://images-na.ssl-images-amazon.com/imag...         55
# 309  ['https://images-na.ssl-images-amazon.com/imag...         37
# 321  ['https://images-na.ssl-images-amazon.com/imag...         39
# 331  ['https://images-na.ssl-images-amazon.com/imag...         63
# 333  ['https://images-na.ssl-images-amazon.com/imag...         41
# 337  ['https://images-na.ssl-images-amazon.com/imag...         23
# 369  ['https://images-na.ssl-images-amazon.com/imag...         51
# 387  ['https://images-na.ssl-images-amazon.com/imag...         31
# 413  ['https://images-na.ssl-images-amazon.com/imag...         27
# 457  ['https://images-na.ssl-images-amazon.com/imag...         28
# 477  ['https://images-na.ssl-images-amazon.com/imag...         28
# 478  ['https://images-na.ssl-images-amazon.com/imag...         23
# 500  ['https://images-na.ssl-images-amazon.com/imag...        605
# 513  ['https://images-na.ssl-images-amazon.com/imag...         41
# 515  ['https://images-na.ssl-images-amazon.com/imag...         39
# 516  ['https://images-na.ssl-images-amazon.com/imag...         34
# 533  ['https://images-na.ssl-images-amazon.com/imag...         23
# 540  ['https://images-na.ssl-images-amazon.com/imag...        149
# 543  ['https://images-na.ssl-images-amazon.com/imag...         70
# 548  ['https://images-na.ssl-images-amazon.com/imag...         36
# 616  ['https://images-na.ssl-images-amazon.com/imag...         25
# 650  ['https://images-na.ssl-images-amazon.com/imag...         40
# 670  ['https://images-na.ssl-images-amazon.com/imag...         33
# 684  ['https://images-na.ssl-images-amazon.com/imag...         30
# 715  ['https://images-na.ssl-images-amazon.com/imag...         29
# 732  ['https://images-na.ssl-images-amazon.com/imag...         36
# 760  ['https://images-na.ssl-images-amazon.com/imag...         29
# 761  ['https://images-na.ssl-images-amazon.com/imag...         27
# 788  ['https://images-na.ssl-images-amazon.com/imag...         26
#
#      vote_average
# 7        1.967949
# 21       3.537037
# 28       2.651163
# 73       3.157895
# 78       2.521739
# 80       2.840000
# 92       3.666667
# 94       3.020000
# 97       2.176471
# 115      3.100000
# 122      2.897436
# 128      2.823529
# 148      2.346154
# 158      3.142857
# 167      2.961538
# 170      3.297297
# 206      3.714286
# 211      4.346154
# 226      3.028571
# 265      3.259259
# 276      3.365079
# 281      2.920000
# 282      3.181818
# 309      2.648649
# 321      3.538462
# 331      2.380952
# 333      3.512195
# 337      1.565217
# 369      2.823529
# 387      3.548387
# 413      2.962963
# 457      3.285714
# 477      2.142857
# 478      3.304348
# 500      2.214876
# 513      2.853659
# 515      3.025641
# 516      3.970588
# 533      3.043478
# 540      2.993289
# 543      3.642857
# 548      2.944444
# 616      3.280000
# 650      3.200000
# 670      3.575758
# 684      2.966667
# 715      2.172414
# 732      1.750000
# 760      3.172414
# 761      2.962963
# 788      3.307692
#
# [51 rows x 21 columns]

# %%
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
dataFramePhone['score'] = dataFramePhone.apply(weighted_rating, axis=1)

dataFrameAppliances['score'] = dataFrameAppliances.apply(weighted_rating, axis=1)
dataFrameSports['score'] = dataFrameSports.apply(weighted_rating, axis=1)

# %%
dataFramePhone = dataFramePhone.sort_values('score', ascending=False)
dataFramePhone[['title', 'vote_count', 'vote_average', 'score']].head(10)
# arr1 = np.array(dataFramePhone['asin'][0:15])
# arr1
# Out:
#                                                  title  vote_count  \
# 211  StarTech.com 1U 12 Port Wall Mount Cat5e 110 P...          26
# 516  OtterBox DEFENDER SERIES for Samsung  Galaxy S...          34
# 543  Fugetek FT-568 Rated Best Selfie Stick in 2015...          70
# 206  Nite Ize Clip Case Sideways Phone Holster - Pr...          28
# 92   EasyAcc 5V 2A Micro USB Travel Charger Portabl...          24
# 21   BESTEK 150W 2-Socket Cigarette Lighter Power A...          54
# 670  CHOETECH USB C Charger, 18W Type-C Power Deliv...          33
# 321  SUPCASE Galaxy Tab 4 7.0(T230 /T231/ T235) Cas...          39
# 387  iCarez Anti Glare (Matte) Premium Screen Prote...          31
# 333  iCarez [Tempered Glass Screen Protector for LG...          41
#
#      vote_average     score
# 211      4.346154  3.816576
# 516      3.970588  3.666881
# 543      3.642857  3.537766
# 206      3.714286  3.490435
# 92       3.666667  3.447068
# 21       3.537037  3.441717
# 670      3.575758  3.428789
# 321      3.538462  3.419552
# 387      3.548387  3.407633
# 333      3.512195  3.406441

# %%
dataFramePhone['asin'][0:15]
# Out:
# 211    B00F7QKHFA
# 516    B00TYTBGOC
# 543    B00W77LAAI
# 206    B00F36YKFC
# 92     B00A9PO5AM
# 21     B003RQBKLC
# 670    B017I7EX46
# 321    B00K5NYTCM
# 387    B00N2KYBSW
# 333    B00KGSW734
# 276    B00HUIL310
# 170    B00DZ0JAMG
# 788    B01EUSL4CU
# 478    B00QAXY27S
# 457    B00P7VSRFC
# Name: asin, dtype: object

# %%
dataFrameAppliances = dataFrameAppliances.sort_values('score', ascending=False)
dataFrameAppliances[['title', 'vote_count', 'vote_average', 'score']].head(10)
# arr2 = np.array(dataFrameAppliances['asin'][0:15])
# arr2
# Out:
#                                                   title  vote_count  \
# 1001  LG LT700P Refrigerator Water Filter, Filters u...          70
# 854   Gardus RLE202 LintEater Rotary Dryer Vent Clea...         760
# 922   Certified Appliance Accessories Braided Stainl...          61
# 1357         Kenmore Elite 9918 Refrigerator Air Filter          26
# 1104  LG LT120F Fresh Air Replacement Filter, 6-Mont...          32
# 1054  Kenmore LG, 46-9690, LT700P, ADQ36006101, ADQ3...          28
# 1443  Waterdrop DA29-00020B Refrigerator Water Filte...          32
# 1233  Danby DAR026A1BDD-3 DAR026A1BDD Compact Refrig...          30
# 1470  FitFabHome 3 Pack Large Non-Stick Oven Liners ...          23
# 878   Range Kleen P10124XN, Black, Style A Porcelain...          48
#
#       vote_average     score
# 1001      4.257143  4.000131
# 854       3.790789  3.773962
# 922       3.885246  3.702526
# 1357      4.115385  3.694127
# 1104      3.906250  3.618404
# 1054      3.892857  3.588475
# 1443      3.687500  3.491131
# 1233      3.700000  3.490796
# 1470      3.695652  3.456787
# 878       3.562500  3.450876

# %%
dataFrameSports = dataFrameSports.sort_values('score', ascending=False)
dataFrameSports[['title', 'vote_count', 'vote_average', 'score']].head(10)
#arr3 = np.array(dataFrameSports['asin'][0:15])
#arr3
#coldstart = np.concatenate((arr1 , arr2 , arr3))
# Out:
#                                                   title  vote_count  \
# 2604  Streamlight 44931 Siege Compact, Rugged 7.25&q...          67
# 1872   KA-BAR Full Size US Marine Corps  Fighting Kn...          43
# 2488  Streamlight 69260 TLR-1 HL Weapon Mount Tactic...          64
# 1916  Coleman Quad LED Lantern Special Edition Ultra...          25
# 2623           Nikon 8397 ACULON AL11 Laser Rangefinder          27
# 2289  CRKT S.P.E.W. EDC Fixed Blade Knife with Sheat...          24
# 1594     Gerber LMF II Survival Knife, Black [22-01629]          63
# 2471  Gerber Bear Grylls Ultimate Pro Knife, Fine Ed...          36
# 1681  Tactical Axe with Sheath &ldquo;Tomahawk&rdquo...          66
# 1721  Gerber Prodigy Survival Knife, Serrated Edge, ...         140
#
#       vote_average     score
# 2604      4.373134  4.077913
# 1872      4.395349  3.985033
# 2488      4.234375  3.965657
# 1916      4.400000  3.833587
# 2623      4.296296  3.800244
# 2289      4.333333  3.787494
# 1594      3.984127  3.779212
# 2471      4.111111  3.762919
# 1681      3.939394  3.752946
# 1721      3.828571  3.742406

# %% [markdown]
# # content-based on feature and description

# %%
stemmer = SnowballStemmer('english') # playing--->play
analyzer = TfidfVectorizer().build_analyzer()

def stemmed_words(doc):
    return (stemmer.stem(w) for w in analyzer(doc))

tfidf = TfidfVectorizer( analyzer = stemmed_words ,
                     ngram_range=(1,1),
                     min_df=3/31858, # if the word is repeated less than three times then I dont care about it
                     max_df=0.5, # if the word is repeated more than 50% then I don't care about it
                     stop_words='english')
tfidf_matrix = tfidf.fit_transform(  df2['description'] + " " + df2['feature'] )

# %%
tfidf_matrix.shape
# Out:
# (5413, 38314)

# %%
cosine_sim1 = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
import pickle

# %%
with open(r'C:\Users\Abdo\Desktop\last year\project\datasets\last datataset isa\cosine_sim1.pkl','wb') as f:
    pickle.dump(cosine_sim1, f)

# %%
with open(r'C:\Users\Abdo\Desktop\last year\project\datasets\last datataset isa\cosine_sim1.pkl','rb') as f:
    cosine_sim1 = pickle.load(f)

# %%
indices1 = pd.Series(df2.index, index=df2['asin'])

# %%
def get_recommendations(asin, cosine_sim , indices):
    
    img_show_asin(asin)
    
    # Get the index of the movie that matches the asin number
    idx = indices[asin]

    # Get the similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx])) # list of tuples [(0,1) , (1,0.5)]

    # Sort the products based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar products
    sim_scores = sim_scores[1:11]  # don't take 0 as we don't take the score with the same product

    # Get the movie indices
    product_indices = [i[0] for i in sim_scores]
    
    img_show_indices( product_indices)
                
    # Return the top 10 most similar movies
    return df2['asin'].iloc[product_indices]

# %%
df
# Out:
#                     0           1    2
# 0      A2VNQ3LQRE0NMO  B0039RFJI4  1.0
# 1       A7GVN0VGQPQZL  B004CYZ7E4  3.0
# 2       A24QDTCMAGCHS  B00180CYFA  2.0
# 3       A7V7URJ0M39AQ  B005CX68VU  3.0
# 4       AYSOURYEYQJBH  B01AIHSL7S  3.0
# ...               ...         ...  ...
# 14409  A1GPKKCPWFQC3S  B000VXB16I  3.0
# 14410   A7EC3HVSCZDP9  B001584Q9M  1.0
# 14411  A1KFGU73RDKCUH  B00IVPU7AO  4.0
# 14412  A1SUA3VWBPRK90  B00KDQSGD4  1.0
# 14413  A36AV0PVTBKDFC  B00FMXXI72  2.0
#
# [14414 rows x 3 columns]

# %%
get_recommendations('B0006TIA8Y' , cosine_sim1  ,indices1)
# Out:
# 3862    B016K0PJ3Q
# 251     B00GYPEM2M
# 5194    B0178HOTOU
# 4565    B01G07W496
# 4082    B006LSQW4I
# 76      B0097AP9KK
# 511     B00T9RTDBM
# 4833    B018LWTYGO
# 4288    B00FEM3OKM
# 3817    B018V7VMNC
# Name: asin, dtype: object

# %%
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df2['brand']+" "+ df2['category'])

# %%
count_matrix.shape
# Out:
# (5413, 6625)

# %%
cosine_sim2 = cosine_similarity(count_matrix,count_matrix)

# %%
import pickle
with open(r'C:\Users\Abdo\Desktop\last year\project\datasets\last datataset isa\cosine_sim2.pkl','wb') as f:
    pickle.dump(cosine_sim2, f)

# %%
with open(r'C:\Users\Abdo\Desktop\last year\project\datasets\last datataset isa\cosine_sim2.pkl','rb') as f:
    cosine_sim2 = pickle.load(f)

# %%
indices2 = pd.Series(df2.index, index=df2['asin'])

# %%
get_recommendations( 'B0006TIA8Y', cosine_sim2 , indices2 )
# Out:
# 2      B0007OWNZO
# 7      B0011YO8S4
# 29     B0042FZ9K0
# 34     B00472M9F6
# 102    B00AUKBUHW
# 112    B00B1Q5LN8
# 146    B00CO3HCR0
# 156    B00DI2TKGM
# 276    B00HUIL310
# 281    B00HZDX42G
# Name: asin, dtype: object

# %%
# if the input is new to the dataset and not yet calculate its cosine with other products
def tf_idftransformer (asin) :
    x = tfidf.transform(  df2[df2['asin']== asin]['description'] + " " +df2[df2['asin']== asin]['feature'] )
    cosine_sim = cosine_similarity(x, tfidf_matrix)
    #cosine_sim1 = cosine_sim1 + cosine_sim  
    indices = pd.Series(df2.index, index=df2['asin'])
    img_show_asin(asin)
    
    
    # Get the index of the movie that matches the asin number
    idx = indices[asin]

    # Get the similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[0]))

    # Sort the products based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar products
    sim_scores = sim_scores[1:11] 

    # Get the movie indices
    product_indices = [i[0] for i in sim_scores]
    
    img_show_indices( product_indices)
                
    # Return the top 10 most similar movies
    return df2['asin'].iloc[product_indices]

# %%
tf_idftransformer('B0006TIA8Y')
# Out:
# 3862    B016K0PJ3Q
# 251     B00GYPEM2M
# 5194    B0178HOTOU
# 4565    B01G07W496
# 4082    B006LSQW4I
# 76      B0097AP9KK
# 511     B00T9RTDBM
# 4833    B018LWTYGO
# 4288    B00FEM3OKM
# 3817    B018V7VMNC
# Name: asin, dtype: object

# %%
def count_transformer (asin) :
    x = count.transform(  df2[df2['asin']== asin]['brand'] + " " +df2[df2['asin']== asin]['category'] )
    cosine_sim = cosine_similarity(x, count_matrix)
    indices = pd.Series(df2.index, index=df2['asin'])
    img_show_asin(asin)
    
    
    # Get the index of the movie that matches the asin number
    idx = indices[asin]

    # Get the similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[0]))

    # Sort the products based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar products
    sim_scores = sim_scores[1:11] 

    # Get the movie indices
    product_indices = [i[0] for i in sim_scores]
    
    img_show_indices( product_indices)
                
    # Return the top 10 most similar movies
    return df2['asin'].iloc[product_indices]

# %%
count_transformer('B0006TIA8Y')
# Out:
# 2      B0007OWNZO
# 7      B0011YO8S4
# 29     B0042FZ9K0
# 34     B00472M9F6
# 102    B00AUKBUHW
# 112    B00B1Q5LN8
# 146    B00CO3HCR0
# 156    B00DI2TKGM
# 276    B00HUIL310
# 281    B00HZDX42G
# Name: asin, dtype: object

# %% [markdown]
# # collaborative filtering with svd

# %%
from surprise.model_selection import train_test_split
from surprise import accuracy
from sklearn.metrics import r2_score
import numpy as np 
import pandas as pd
from surprise import Reader, Dataset, SVD , dump
from surprise.model_selection import cross_validate
from sklearn.metrics import confusion_matrix , classification_report
from sklearn import preprocessing
from collections import defaultdict
from surprise.model_selection import KFold
from sklearn.metrics import RocCurveDisplay
import os
import random
random.seed(42)
np.random.seed(42)

# %%
def precision_recall_at_k(predictions, k=10, threshold=3.5):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(
            ((true_r >= threshold) and (est >= threshold))
            for (est, true_r) in user_ratings[:k]
        )

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. We here set it to 0.

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. We here set it to 0.

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0

    return precisions, recalls

# %%
def get_top_n(predictions, n):
    """Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    """

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
def collaborative_recommendation(userId , top_n):
    for asin in top_n[userId]:
        img_show_asin(asin[0])

# %%
ratings = pd.read_csv(r'C:\Users\Abdo\Desktop\notFound2_ratings5407.csv')
ratings
# Out:
#                userId        asin  rating   timestamp
# 0      A2HM2RMX1CBZGM  B0006TIA8Y     1.0  1353024000
# 1      A2CQEJH6SN11EA  B0006TIA8Y     1.0  1204848000
# 2      A2JE174WR70HFD  B000M06LME     1.0  1450742400
# 3      A2ME0DNOOLVK2T  B000M06LME     1.0  1434326400
# 4       AB8G69EUC0UPZ  B000NO7NC6     1.0  1500681600
# ...               ...         ...     ...         ...
# 71812  A1ZT9RQMTBKTCK  B008RF0M9O     5.0  1409961600
# 71813  A2Q8T2BQOR0XW3  B005OK12HQ     5.0  1441670400
# 71814  A2A27XRH4MQJEQ  B0000CFPK8     5.0  1388620800
# 71815   AJCFIMQZR09BM  B00KIGV3C0     5.0  1464048000
# 71816  A3LMUTISAINC4D  B01DL9JEHG     5.0  1524009600
#
# [71817 rows x 4 columns]

# %%
#ratings = ratings.sort_values('Rating', ascending=True)
#ratings = ratings[ : 24844171-20100000]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(ratings[['userId', 'asin', 'rating']], reader)

# %%
svd = SVD(n_factors= 30 , n_epochs= 20 , lr_all = 0.005 , reg_all = 0.02 , random_state=42  )
cross_validate(svd, data, measures=["RMSE", "MAE"], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2216  1.2245  1.2322  1.2223  1.2264  1.2254  0.0038
# MAE (testset)     0.9983  1.0031  1.0107  0.9989  1.0039  1.0030  0.0045
# Fit time          0.58    0.63    0.57    0.63    0.59    0.60    0.02
# Test time         0.12    0.11    0.12    0.10    0.11    0.11    0.01
# {'test_rmse': array([1.22159361, 1.22446779, 1.23218682, 1.2222842 , 1.22638126]),
#  'test_mae': array([0.9983031 , 1.0031306 , 1.01069757, 0.99886509, 1.0039291 ]),
#  'fit_time': (0.5834410190582275,
#   0.6283185482025146,
#   0.572521448135376,
#   0.6272826194763184,
#   0.5934114456176758),
#  'test_time': (0.118682861328125,
#   0.1077122688293457,
#   0.12262177467346191,
#   0.10274243354797363,
#   0.10571742057800293)}

# %%
trainset, testset = train_test_split(data, test_size=0.20 , shuffle = True , random_state= 42 )

#trainset = data.build_full_trainset()
svd.fit(trainset)
#testset = trainset.build_testset()
predictions = svd.test(testset)

accuracy.rmse(predictions)
# Then compute RMSE
#trainset
# Out:
# RMSE: 1.2265
# 1.2265253802264233

# %%
y = []
for i in range(len(predictions)) :
  y.append(predictions[i].est)
y = pd.DataFrame(y)
y = y[0]
y
# Out:
# 0        3.605505
# 1        1.768817
# 2        3.199119
# 3        3.191876
# 4        3.075562
#            ...
# 14359    2.128918
# 14360    2.007519
# 14361    2.700602
# 14362    2.198107
# 14363    4.427246
# Name: 0, Length: 14364, dtype: float64

# %%
df = pd.DataFrame(testset)
x = df[2]
x
# Out:
# 0        1.0
# 1        2.0
# 2        1.0
# 3        4.0
# 4        4.0
#         ...
# 14359    3.0
# 14360    1.0
# 14361    4.0
# 14362    1.0
# 14363    2.0
# Name: 2, Length: 14364, dtype: float64

# %%
r2_score(x,y)
# Out:
# 0.24184634105631253

# %%
def thresh (num , thresh = 2.5):
    if num >  thresh:
        return 1
    else:
        return 0

# %%
pred= y.apply(thresh)
pred
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 14359    0
# 14360    0
# 14361    1
# 14362    0
# 14363    1
# Name: 0, Length: 14364, dtype: int64

# %%
y_test = x.apply(thresh)

# %%
y_test
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 14359    1
# 14360    0
# 14361    1
# 14362    0
# 14363    0
# Name: 2, Length: 14364, dtype: int64

# %%
print(classification_report(y_test, pred ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.30      0.44      4781
#            1       0.73      0.97      0.84      9583
#
#     accuracy                           0.75     14364
#    macro avg       0.78      0.63      0.64     14364
# weighted avg       0.77      0.75      0.70     14364

# %%
RocCurveDisplay.from_predictions(y_test , pred)

# %%
ratings['rating'].value_counts()
# Out:
# 3.0    17046
# 4.0    16055
# 5.0    15253
# 1.0    14216
# 2.0     9247
# Name: rating, dtype: int64

# %%
precisions, recalls = precision_recall_at_k(predictions, k= 10, threshold=2.5)

# %%
print(sum(prec for prec in precisions.values()) / len(precisions))
print(sum(rec for rec in recalls.values()) / len(recalls))
# Out:
# 0.6475747820254862
# 0.6589244993772156

# %%
svd.predict('A2HM2RMX1CBZGM','B0006TIA8Y')
# Out:
# Prediction(uid='A2HM2RMX1CBZGM', iid='B0006TIA8Y', r_ui=None, est=2.9681632071156767, details={'was_impossible': False})

# %%
# return the products that has not been rated yet
def build_anti_testset(self, userId, fill=None ):
        """Return a list of ratings that can be used as a testset in the
        :meth:`test() <surprise.prediction_algorithms.algo_base.AlgoBase.test>`
        method.

        The ratings are all the ratings that are **not** in the trainset, i.e.
        all the ratings :math:`r_{ui}` where the user :math:`u` is known, the
        item :math:`i` is known, but the rating :math:`r_{ui}`  is not in the
        trainset. As :math:`r_{ui}` is unknown, it is either replaced by the
        :code:`fill` value or assumed to be equal to the mean of all ratings
        :meth:`global_mean <surprise.Trainset.global_mean>`.

        Args:
            fill(float): The value to fill unknown ratings. If :code:`None` the
                global mean of all ratings :meth:`global_mean
                <surprise.Trainset.global_mean>` will be used.

        Returns:
            A list of tuples ``(uid, iid, fill)`` where ids are raw ids.
        """
        fill = self.global_mean if fill is None else float(fill)

        anti_testset = []
        user_items = {j for (j, _) in self.ur[userId]}
        anti_testset += [
                (self.to_raw_uid(real_trainset.to_inner_uid(userId)), self.to_raw_iid(i), fill)
                for i in self.all_items()
                if i not in user_items
            ]
        return anti_testset

# %%
real_trainset = data.build_full_trainset()
svd.fit(real_trainset)
real_testset = build_anti_testset(real_trainset   , 'A2HM2RMX1CBZGM' )
predictions = svd.test(real_testset)
top_n = get_top_n(predictions, n=20)
collaborative_recommendation('A2HM2RMX1CBZGM' , top_n)

# %%
file_name = os.path.expanduser(r"C:\Users\Abdo\Desktop\last year\project\datasets\last datataset isa\dump_file")
dump.dump(file_name, algo=svd)
_, loaded_algo = dump.load(file_name)

# %% [markdown]
# # embedding

# %%
from keras.layers import Input, Embedding, Flatten, Dot, Dense , Concatenate , StringLookup, BatchNormalization,Dropout
from keras.models import Model , load_model
from sklearn.model_selection import train_test_split
import tensorflow as tf
tf.random.set_seed(42)

# %%
ratings_dataset = pd.read_csv(r'C:\Users\Abdo\Desktop\notFound2_ratings5407.csv')

# %%
ratings_dataset.userId.value_counts()
# Out:
# A25C30G90PKSQA    206
# A3TMNU7VNK5JJE    206
# A1WD61B0C3KQZB    103
# A21TPY9BVC9IKZ     44
# AMY6O4Z9HINO0      39
#                  ...
# A4N66SXFFYS0C       2
# A3QWTB7JGLYWBG      2
# A2P7O8WQCL3KYR      2
# A16BMP3TNGEI74      2
# ARJEHF00TBVBD       2
# Name: userId, Length: 32636, dtype: int64

# %%
train, test = train_test_split(ratings_dataset, test_size=0.2, random_state=42 , shuffle=True)
n_users = len(ratings_dataset['userId'].unique())
n_items = len(ratings_dataset['asin'].unique())

# %%
userId_lookup = StringLookup(vocabulary = ratings_dataset['userId'].unique(), mask_token = None )
asin_lookup = StringLookup(vocabulary = ratings_dataset['asin'].unique(), mask_token = None )


# creating item embedding
item_input = Input(shape=[1], name="Item-Input" , dtype= object)
item_input1 = asin_lookup(item_input)
item_embedding = Embedding(n_items+1, 8, name="Item-Embedding")(item_input1) # fourth root of unique values
item_vec = Flatten(name="Flatten-Items")(item_embedding)

# creating user embedding
user_input = Input(shape=[1], name="User-Input" , dtype= object)
user_input1 = userId_lookup(user_input)
user_embedding = Embedding(n_users+1, 8, name="User-Embedding")(user_input1)
user_vec = Flatten(name="Flatten-Users")(user_embedding)


prod = Dot(name="Dot-Product", axes=1)([item_vec, user_vec])

# concatenate features
conc = Concatenate()([item_vec, user_vec])

# add fully-connected-layers
fc1 = Dense(64, activation='relu')(conc)

fc1_bn = BatchNormalization(name='batch-norm-1')(fc1)
fc1_dropout = Dropout(0.5)(fc1_bn)

fc2 = Dense(16, activation='relu')(fc1_dropout)

fc2_bn = BatchNormalization(name='batch-norm-2')(fc2)
fc2_dropout = Dropout(0.5)(fc2_bn)

pred_mlp = Dense(8, name='pred-mlp', activation='relu')(fc2_dropout)

fc3 = Concatenate()([prod, pred_mlp])

out = Dense(1 , activation='sigmoid' )(fc3)

# Create model and compile it
model2 = Model([user_input, item_input], out)
model2.compile(optimizer='adam', loss='binary_crossentropy'  , metrics= ['accuracy'])

# %%
labels = train['rating'].apply(thresh)

# %%
if os.path.exists(r'C:\Users\Abdo\Desktop\last year\project\datasets\last datataset isa\embedding_model.h5'):
    model2 = load_model(r'C:\Users\Abdo\Desktop\last year\project\datasets\last datataset isa\embedding_model.h5')
else:
    history = model2.fit([train.userId, train.asin], labels, batch_size=64  , epochs=8 ,  verbose=1)
    model2.save(r'C:\Users\Abdo\Desktop\last year\project\datasets\last datataset isa\embedding_model.h5')
    plt.plot(history.history['loss'])
    plt.xlabel("Epochs")
    plt.ylabel("Training Error")
# Out:
# Epoch 1/8
# 898/898 [==============================] - 15s 15ms/step - loss: 0.6841 - accuracy: 0.6167
# Epoch 2/8
# 898/898 [==============================] - 13s 14ms/step - loss: 0.6115 - accuracy: 0.6737
# Epoch 3/8
# 898/898 [==============================] - 13s 14ms/step - loss: 0.4941 - accuracy: 0.7617
# Epoch 4/8
# 898/898 [==============================] - 13s 14ms/step - loss: 0.2993 - accuracy: 0.8832
# Epoch 5/8
# 898/898 [==============================] - 13s 14ms/step - loss: 0.2090 - accuracy: 0.9202
# Epoch 6/8
# 898/898 [==============================] - 13s 14ms/step - loss: 0.1595 - accuracy: 0.9365
# Epoch 7/8
# 898/898 [==============================] - 13s 14ms/step - loss: 0.1241 - accuracy: 0.9510
# Epoch 8/8
# 898/898 [==============================] - 13s 14ms/step - loss: 0.1071 - accuracy: 0.9588

# %%
labels1 = test['rating'].apply(thresh)

# %%
model2.evaluate([test.userId, test.asin], labels1)
# Out:
# 449/449 [==============================] - 3s 5ms/step - loss: 1.0957 - accuracy: 0.7669
# [1.0957207679748535, 0.7669172883033752]

# %%
predictions = model2.predict([test['userId'].head(10), test['asin'].head(10)])

[print(predictions[i], test.rating.iloc[i]) for i in range(0,10)]
# Out:
# 1/1 [==============================] - 0s 147ms/step
# [0.99434507] 5.0
# [0.01059925] 5.0
# [0.0014382] 4.0
# [0.24588983] 2.0
# [0.9676042] 4.0
# [0.05119833] 1.0
# [0.00115586] 2.0
# [0.9999949] 5.0
# [0.9999896] 3.0
# [0.07149377] 4.0
# [None, None, None, None, None, None, None, None, None, None]

# %%
item_data = np.array(list(set(ratings_dataset.asin)))
item_data[:5]
# Out:
# array(['B01GHVITB2', 'B0058DQLO8', 'B003YGSPW2', 'B005ZWBHBY',
#        'B008YDSJT4'], dtype='<U10')

# %%
# predict for user 'AZB4CQ9JZSUQB'
user = np.array(['AZB4CQ9JZSUQB' for i in range(len(item_data))])
user[:5]
# Out:
# array(['AZB4CQ9JZSUQB', 'AZB4CQ9JZSUQB', 'AZB4CQ9JZSUQB', 'AZB4CQ9JZSUQB',
#        'AZB4CQ9JZSUQB'], dtype='<U13')

# %%
predictions = model2.predict([user, item_data])

predictions = np.array([a[0] for a in predictions])

recommended_indices = (-predictions).argsort()[:5]

# print the best five items 
print(item_data[recommended_indices])
# Out:
# 169/169 [==============================] - 1s 4ms/step
# ['B00S6DQ37W' 'B00KO4SBR6' 'B01GZNT27C' 'B00VGEYX5M' 'B00EZ6L6B2']

# %%
predictions[recommended_indices]
# Out:
# array([0.99997246, 0.9999347 , 0.9998796 , 0.99986017, 0.9998467 ],
#       dtype=float32)

# %%
df2[df2['asin'].isin(item_data[recommended_indices])]
# Out:
#                                                category  \
# 341   ['Cell Phones & Accessories', 'Accessories', '...
# 493   ['Cell Phones & Accessories', 'Cases, Holsters...
# 827   ['Cell Phones & Accessories', 'Accessories', '...
# 2663  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 3212  ['Sports & Outdoors', 'Sports & Fitness', 'Exe...
#
#                                                   tech1  \
# 341                                                 NaN
# 493    class="a-keyvalue prodDetTable" role="present...
# 827                                                 NaN
# 2663   class="a-keyvalue prodDetTable" role="present...
# 3212                                                NaN
#
#                                             description  \
# 341   ['The S1 is the first professional smartphone ...
# 493   ['', 'The smart-phone case is a handheld elect...
# 827   ['<b> Fast Charge Wireless Charging Pad </b> <...
# 2663  ['Mr. , beams, green, 260 lumen, ultra bright ...
# 3212  ["DRI-EQUIP(tm) Women's All Sport Neon Color H...
#
#                                                     fit  \
# 341                                                 NaN
# 493                                                 NaN
# 827                                                 NaN
# 2663                                                NaN
# 3212   class="a-normal a-align-center a-spacing-smal...
#
#                                                   title  \
# 341   Shoulderpod S1 Professional Smartphone Rig, Tr...
# 493   Urvoix Case Cover for Samsung Galaxy S9 S9 Plu...
# 827   Nekteck Wireless Charger Fast Wireless Chargin...
# 2663  Mr. Beams MB470 UltraBright LED Camping Lanter...
# 3212  DRI-Equip Women's Neon Color High Visibility A...
#
#                                                also_buy tech2        brand  \
# 341   ['B0149KBPB4', 'B01MXW55PD', 'B00WSNWFM8', 'B0...   NaN  Shoulderpod
# 493   ['B011SWIOWO', 'B00889AVO0', 'B01FV5YVTE', 'B0...   NaN       Urvoix
# 827   ['B01JRTHAE8', 'B00XN57ZU2', 'B01KHEIXNE', 'B0...   NaN      Nekteck
# 2663  ['B00MH4QKP6', 'B01MFAJF86', 'B000JCCT9Y', 'B0...   NaN    Mr. Beams
# 3212  ['B00KODZGSY', 'B00NDZU1EE', 'B07C1RYZZC', 'B0...   NaN    Joe's USA
#
#                                                 feature  \
# 341   ['S1 is the first Professional Smartphone Rig ...
# 493   ['Compatible fits for Samsung Galaxy Note 9, N...
# 827   ['IMPORTANT NOTE: QC 2.0/3.0 Adaptive Fast Cha...
# 2663  ['Auto shut-off feature turns this LED lantern...
# 3212  ["DRI-EQUIP(tm) Women's All Sport Neon Color H...
#
#                                                    rank  ... details  \
# 341   ['>#42,555 in Cell Phones & Accessories (See T...  ...      {}
# 493   ['>#234,634 in Tools & Home Improvement (See t...  ...      {}
# 827   ['>#187,490 in Cell Phones & Accessories (See ...  ...      {}
# 2663  ['>#223,676 in Tools & Home Improvement (See t...  ...      {}
# 3212             144,637 in Clothing, Shoes & Jewelry (  ...      {}
#
#                                                main_cat  \
# 341                           Cell Phones & Accessories
# 493                            Tools & Home Improvement
# 827                                     All Electronics
# 2663                           Tools & Home Improvement
# 3212  <img src="https://images-na.ssl-images-amazon....
#
#                                            similar_item  \
# 341    class="a-bordered a-horizontal-stripes  a-spa...
# 493    class="a-bordered a-horizontal-stripes  a-spa...
# 827    class="a-bordered a-horizontal-stripes  a-spa...
# 2663                                                NaN
# 3212                                                NaN
#
#                                                    date           price  \
# 341                                     August 29, 2014          $39.99
# 493                                    January 13, 2015           $7.99
# 827                                       June 13, 2016          $11.99
# 2663                                  September 4, 2013           $1.41
# 3212  <div class="a-fixed-left-grid a-spacing-none">...  $8.98 - $18.94
#
#             asin                                           imageURL  \
# 341   B00KO4SBR6  ['https://images-na.ssl-images-amazon.com/imag...
# 493   B00S6DQ37W  ['https://images-na.ssl-images-amazon.com/imag...
# 827   B01GZNT27C  ['https://images-na.ssl-images-amazon.com/imag...
# 2663  B00EZ6L6B2  ['https://images-na.ssl-images-amazon.com/imag...
# 3212  B00VGEYX5M  ['https://images-na.ssl-images-amazon.com/imag...
#
#                                         imageURLHighRes vote_count  \
# 341   ['https://images-na.ssl-images-amazon.com/imag...         18
# 493   ['https://images-na.ssl-images-amazon.com/imag...          8
# 827   ['https://images-na.ssl-images-amazon.com/imag...          6
# 2663  ['https://images-na.ssl-images-amazon.com/imag...         16
# 3212  ['https://images-na.ssl-images-amazon.com/imag...          2
#
#       vote_average
# 341       3.666667
# 493       4.000000
# 827       3.500000
# 2663      3.875000
# 3212      4.000000
#
# [5 rows x 21 columns]

# %% [markdown]
# # recommendation for images

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import matplotlib.image as mpimg
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # accessing directory structure
import tensorflow as tf
import keras
from keras import Model
from tensorflow.keras.applications import ResNet50
from keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import GlobalMaxPooling2D
import cv2
import urllib.request
from tensorflow.keras.utils import img_to_array
import requests
import PIL.Image as Image
import io
tf.__version__
# Out:
# '2.9.1'

# %%
# Input Shape
img_width, img_height, _ = 224, 224, 3 #load_image(df.iloc[0].image).shape

# Pre-Trained Model
base_model = ResNet50(weights='imagenet', 
                      include_top=False, 
                      input_shape = (img_width, img_height, 3))
base_model.trainable = False

# Add Layer Embedding
model = keras.Sequential([
    base_model,
    GlobalMaxPooling2D()
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_max_pooling2d_1 (Glo  (None, 2048)             0
#  balMaxPooling2D)
#
# =================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# this code is to store the images from the url

for asin in df2['asin']:
    image_url = literal_eval(df2[df2['asin'] == asin]['imageURLHighRes'].values[0])[0]
    img_data = requests.get(image_url).content
    #img_data = img_data.decode('utf-8')
    #img_data = img_data.encode()
    #arr = np.asarray(bytearray(img_data), dtype=np.uint8)
    #img_data = cv2.imdecode(arr, -1 )
    #img_data = Image.open(io.BytesIO(img_data))
    #height, width, channels = scipy.ndimage.imread(img_data).shape
    
    
    
    img_data = np.asarray(bytearray(img_data), dtype=np.uint8)
    img_data = cv2.imdecode(img_data, -1 ) # 'Load it as it is'
    #img_data = Image.open(BytesIO(img_data))
    #print(type(img_data))
    #if  len(img_data.shape)== 2:
        #img_data = np.expand_dims(img_data, axis=1)
    if  len(img_data.shape) > 2:
        if img_data.shape[2] ==1:
            img_data = np.squeeze(img_data, axis=2)  # axis=2 is channel dimension 
        
        
    img_data = Image.fromarray(img_data)
      
    # saving the final output 
    # as a PNG file
    img_data.save('C:\\Users\\Abdo\\Desktop\\last year\\project\\datasets\\last datataset isa\\images' + "\\" + asin + '.jpg')
        
   # with open('C:\\Users\\Abdo\\Desktop\\last year\\project\\datasets\\last datataset isa\\images' + "\\" + asin + '.jpg', 'wb') as handler:
        #handler.write(img_data)

# %%
def get_embedding1(model, asin):
    # Reshape
    img = cv2.imread('C:\\Users\\Abdo\\Desktop\\last year\\project\\datasets\\last datataset isa\\images' + "\\" + asin + '.jpg')
        
    if img.shape[2] == 1:
        img = cv2.merge((img,img,img))   
    
    
    #img = tf.keras.utils.load_img(img, target_size=(img_width, img_height))
    
    width = 224
    height = 224
    
    dsize = (width, height)
    output = cv2.resize(img, dsize)
    
    # img to Array
    x   = img_to_array(output)
    # Expand Dim (1, w, h)
    x   = np.expand_dims(x, axis=0)
    # Pre process Input
    x   = preprocess_input(x)
    return model.predict(x , verbose = False).reshape(-1)

# %%
def get_embedding2(model, asin):
    # Reshape
    
    #response = requests.get(literal_eval(df2[df2['asin'] == asin]['imageURLHighRes'].values[0])[0])
    #img = Image.open(BytesIO(response.content))
    print (asin)
    
    with urllib.request.urlopen(literal_eval(df2[df2['asin'] == asin]['imageURLHighRes'].values[0])[0]) as url:
        s = url.read()
    
    #req = urllib.urlopen(literal_eval(df2[df2['asin'] == asin]['imageURLHighRes'].values[0])[0])
    arr = np.asarray(bytearray(s), dtype=np.uint8)
    img = cv2.imdecode(arr, -1 ) # 'Load it as it is'
    
    if len(img.shape) == 2:
        img = img[:,: ,np.newaxis]
    
        
    if img.shape[2] == 1:
        img = cv2.merge((img,img,img))   
    
    
    #img = tf.keras.utils.load_img(img, target_size=(img_width, img_height))
    
    width = 224
    height = 224
    
    dsize = (width, height)
    output = cv2.resize(img, dsize)
    
    # img to Array
    x   = img_to_array(output)
    # Expand Dim (1, w, h)
    x   = np.expand_dims(x, axis=0)
    # Pre process Input
    x   = preprocess_input(x)
    return model.predict(x , verbose = False).reshape(-1)

# %%
emb = get_embedding1(model, "B00KO4SBR6")
emb.shape
# Out:
# (2048,)

# %%
img_show_asin("B00EZ6L6B2")

# %%
df_sample      = df2
map_embeddings = df_sample['asin'].apply(lambda img: get_embedding1(model, img))
df_embs        = map_embeddings.apply(pd.Series)

# %%
df_embs
# Out:
#           0         1         2         3         4          5          6     \
# 0     1.770079  4.830957  1.813573  1.866431  1.682286   0.825338   0.346571
# 1     1.028006  1.283671  1.038543  2.699382  2.146210   6.169525   1.934242
# 2     2.115087  1.545836  0.554282  5.458855  9.408823   0.300753   5.826110
# 3     3.376249  4.759518  4.030020  0.000000  5.510024   0.799500   0.702566
# 4     1.663719  5.967355  0.678915  6.442191  0.000000   1.710597  11.989994
# ...        ...       ...       ...       ...       ...        ...        ...
# 5408  0.000000  2.094768  0.147115  1.611190  9.188946   4.292393   1.970783
# 5409  0.374322  0.000000  0.022958  0.000000  5.748634   3.798195   3.102803
# 5410  3.357991  3.925269  4.856652  5.647555  1.065655   2.531837   2.778962
# 5411  1.894702  8.115377  9.130134  0.000000  1.222085  18.521479   1.644167
# 5412  0.000000  2.249449  3.019839  0.000000  6.771114   0.072345   3.954488
#
#            7         8         9     ...      2038       2039       2040  \
# 0      4.094207  0.971939  8.734591  ...  1.421413   0.531328   8.354727
# 1      0.553635  0.332198  2.433579  ...  0.000000   6.491083  12.740483
# 2     13.434776  7.949846  1.339605  ...  0.316789   2.906056   0.000000
# 3      8.114180  1.164904  1.071515  ...  1.362664  10.777292   0.856648
# 4     10.265745  0.000000  0.758911  ...  8.491177   4.426236   6.638884
# ...         ...       ...       ...  ...       ...        ...        ...
# 5408   6.501966  2.333096  0.000000  ...  9.071722   6.955762  12.486596
# 5409   8.868022  0.000000  6.650129  ...  0.000000   0.806765   9.188884
# 5410   1.331654  4.200613  2.207933  ...  4.285688  14.036607   7.868716
# 5411   5.617251  3.829564  0.000000  ...  2.220611   7.480323   0.416562
# 5412  16.250683  1.287331  6.663420  ...  2.579229  14.479548   5.391686
#
#           2041       2042      2043       2044      2045      2046       2047
# 0     1.340987   1.526076  1.733318  10.038422  1.725080  2.228156  13.035896
# 1     3.456471   0.078369  2.911051   6.214513  0.500503  2.877556   0.000000
# 2     0.418002   4.983727  0.287098  16.128372  0.000000  0.000000  13.536517
# 3     0.000000  20.683949  0.000000   9.334636  0.649470  0.000000   0.316461
# 4     0.628979   4.036504  0.000000   7.749382  0.352573  3.174265  15.577497
# ...        ...        ...       ...        ...       ...       ...        ...
# 5408  0.785777  17.346371  5.093657   3.526646  4.758188  0.443099   1.813052
# 5409  3.792042   2.739504  0.330961   5.333526  0.000000  0.000000   0.000000
# 5410  0.000000   0.000000  4.171287   4.174564  5.554296  2.384925   3.676951
# 5411  0.352178  16.599091  1.246589  12.144701  6.293598  0.954338   0.328002
# 5412  4.678198  20.262571  0.813743   7.792352  0.361282  5.072766   0.000000
#
# [5413 rows x 2048 columns]

# %%
cosine_sim3 = cosine_similarity(df_embs,df_embs)

# %%
indices3 = pd.Series(df2.index, index=df2['asin'])

# %%
get_recommendations( 'B00EZ6L6B2', cosine_sim3 , indices3 )
# Out:
# 2900    B00KBHO0V2
# 1795    B0017IFSIS
# 2139    B004XFX24O
# 2363    B007ZT5Y14
# 2207    B005HHTJLC
# 2604    B00DII7CTI
# 3557    B01C5QSENQ
# 3215    B00VTJJ5DE
# 2537    B00C7I4Q1C
# 2076    B004AKP7AO
# Name: asin, dtype: object

# %% [markdown]
# # handling ratings

# %%
meta = pd.read_csv(r'C:\Users\Abdo\Desktop\mini_metadata32000.csv')

# %%
ratings = pd.read_csv(r'C:\Users\Abdo\Desktop\last year\project\datasets\Books.csv')

# %%
ratings

# %%
ratings.columns = ['userId' ,'asin',  'rating' , 'timestamp']

# %%
ratings.columns = ['asin', 'userId' , 'rating' , 'timestamp']

# %%
ratings = ratings[['userId','asin' , 'rating' , 'timestamp']]

# %%
ratings

# %%
y = ratings['userId'].value_counts()
y

# %%
maping = pd.DataFrame(ratings['userId'].value_counts())
condition = maping[(maping['userId'] >= 35) &(maping['userId'] <= 1000)].index

# %%
condition

# %%
ratings = ratings[ratings['userId'].isin(condition)]

# %%
ratings

# %%
maping2 = pd.DataFrame(ratings['asin'].value_counts())
condition2 = maping2[(maping2['asin'] >= 35)&  (maping2['asin'] <= 1000) ].index

# %%
condition2

# %%
ratings = ratings[ratings['asin'].isin(condition2)]

# %%
t = ratings['asin'].unique()
len(t)

# %%
t

# %%
ratings['userId'].value_counts()

# %%
ratings['asin'].value_counts()

# %%
meta = meta.drop('asin', axis=1)

# %%
meta['asin'] = t[0:31858]

# %%
ratings = ratings[ratings['asin'].isin(meta['asin'])]

# %%
meta.to_csv(r'C:\Users\Abdo\Desktop\last_mini_metadata32000.csv' , index=False)

# %%
ratings.rename(columns = {'movieId':'asin'}, inplace = True)

# %%
ratings['rating'].value_counts()

# %%
ratings = ratings[ratings['rating'] != 0]

# %%
#ratings = ratings[:19536645-2800000]

# %%
ratings['rating'].value_counts()

# %%
len(ratings['asin'].unique())

# %%
ratings['asin'].value_counts()

# %%
x = 0
y = ratings['userId'].value_counts()
y

# %%
for i in range(31858):
    if (y.iloc[i] == 1 ):
        x = x + 1

# %%
x

# %%
ratings.to_csv(r'C:\Users\Abdo\Desktop\moviesonly32000.csv' , index=False)

# %%
ratings

# %%
ratings[:22163126-2000000]['asin'].value_counts().tail(100)

# %%
ratings = ratings[:22163126-2000000]
